# %% [markdown]
# # BÁSICO DE PYMONGO

# %%
import json
from pymongo import MongoClient

# %%
# conexão com o cliente
client = MongoClient('localhost', 27017)

# %%
# Mostra um lista dos databases já criados no seu localhost
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'pokemon_center']

# %%
# criando um database 
db = client.disney_center

# %%
# criando uma collection
collection = db.disney

# %%
# importando o documento na collection disney
with open('./data/disney.json') as file:
    data_file = json.load(file)
    
    if isinstance(data_file, list):
        collection.insert_many(data_file)
    else:
        collection.insert_one(data_file)

# %%
# criando outra collection
collection2 = db.descriptions

# %%
# importando o documento na collection description
with open('./data/descriptions.json') as file:
    data_file = json.load(file)
    
    if isinstance(data_file, list):
        collection2.insert_many(data_file)
    else:
        collection2.insert_one(data_file)

# %%
# mostrando os databases
client.list_database_names()

# depois de importar os documentos que o database parece
# Out:
# ['admin', 'config', 'disney_center', 'local', 'pokemon_center']

# %% [markdown]
# ### Respondendo com query

# %% [markdown]
# #### Dimensão dos dados na collection disney

# %%
query = collection.find()

count = 0
for x in query:
    count += 1
print(count)
# Out:
# 1450

# %% [markdown]
# #### Quantos são 'type' 'Movie':

# %%
query = collection.find({'type': { '$eq': 'Movie'}})

count = 0
for x in query:
    count += 1
print(count)
# Out:
# 1052

# %% [markdown]
# #### Quantos são diferentes de 'Movie':

# %%
query = collection.find({'type': {'$not': { '$eq': 'Movie'}}})

count = 0
for x in query:
    count += 1
print(count)
# Out:
# 398

# %% [markdown]
# #### Dos 'Movie' quantos são 'Animation':

# %%
query = collection.find({'$and': [{'type': {'$eq': 'Movie'}}, {'listed_in': 'Animation'}]})

count = 0
for x in query:
    count +=1
print(count)
# Out:
# 381

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('636a3e8a31a8e2eab5264231'),
#  'date_added': {'$date': '2021-11-26T00:00:00.000Z'},
#  'show_id': 's1',
#  'type': 'Movie',
#  'title': 'Duck the Halls: A Mickey Mouse Christmas Special',
#  'director': ['Alonso Ramirez Ramos', 'Dave Wasson'],
#  'cast': ['Chris Diamantopoulos',
#   'Tony Anselmo',
#   'Tress MacNeille',
#   'Bill Farmer',
#   'Russi Taylor',
#   'Corey Burton'],
#  'country': [''],
#  'release_year': 2016,
#  'duration': 23,
#  'listed_in': ['Animation', 'Family'],
#  'rating': 'TV-G',
#  'description': 'Join Mickey and the gang as they duck the halls!'}

# %% [markdown]
# #### Os 5 primeiros 'TV Show' de 'Fantasy' do database:

# %%
query = collection.find({'$and': [{'type': {'$not': {'$eq': 'Movie'}}},
                                  {'listed_in': {'$eq': 'Fantasy'}}]}).limit(5)
for x in query:
    print(' ')
    print(x)
    print(' ')
# Out:
#
# {'_id': ObjectId('636a3e8a31a8e2eab5264274'), 'date_added': {'$date': '2021-10-13T00:00:00.000Z'}, 'show_id': 's68', 'type': 'TV Show', 'title': "Zombies: Addison's Moonstone Mystery", 'director': [''], 'cast': [''], 'country': [''], 'release_year': 2020, 'duration': 1, 'listed_in': ['Animation', 'Coming of Age', 'Fantasy'], 'rating': 'TV-G', 'description': 'Things are smooth sailing at Seabrook High until ...'}
#
#
# {'_id': ObjectId('636a3e8a31a8e2eab5264286'), 'date_added': {'$date': '2021-09-29T00:00:00.000Z'}, 'show_id': 's86', 'type': 'TV Show', 'title': 'Disney Vampirina', 'director': [''], 'cast': ['Isabella Crovetti', 'Lauren Graham', 'James Van Der Beek', 'Jordan Davis', 'Wanda Sykes', 'Mitchell Whitfield'], 'country': ['Ireland', 'United States'], 'release_year': 2017, 'duration': 3, 'listed_in': ['Animation', 'Fantasy', 'Kids'], 'rating': 'TV-Y7', 'description': 'Vampirina is the new girl in town!'}
#
#
# {'_id': ObjectId('636a3e8a31a8e2eab526429c'), 'date_added': {'$date': '2021-09-15T00:00:00.000Z'}, 'show_id': 's108', 'type': 'TV Show', 'title': 'Miraculous: Tales Of Ladybug & Cat Noir', 'director': [''], 'cast': ['Cristina Vee', 'Bryce Papenbrook', 'Keith Silverstein', 'Mela Lee', 'Max Mittelman', 'Carrie Keranen'], 'country': ['France', 'South Korea', 'Japan', 'United States'], 'release_year': 2015, 'duration': 1, 'listed_in': ['Action-Adventure', 'Animation', 'Fantasy'], 'rating': 'TV-Y7', 'description': 'Superheroes Ladybug and Cat Noir protect the city.'}
#
#
# {'_id': ObjectId('636a3e8a31a8e2eab52642a2'), 'date_added': {'$date': '2021-09-08T00:00:00.000Z'}, 'show_id': 's114', 'type': 'TV Show', 'title': 'Mira, Royal Detective', 'director': [''], 'cast': ['Leela Ladnier', 'Utkarsh Ambudkar', 'Roshni Edwards', 'Kal Penn', 'Kamran Lucas'], 'country': ['United States'], 'release_year': 2020, 'duration': 2, 'listed_in': ['Animation', 'Fantasy', 'Kids'], 'rating': 'TV-Y', 'description': 'Mira is the new royal detective in the land of Jalpur!'}
#
#
# {'_id': ObjectId('636a3e8a31a8e2eab52642e9'), 'date_added': {'$date': '2021-07-02T00:00:00.000Z'}, 'show_id': 's185', 'type': 'TV Show', 'title': "Disney Raven's Home", 'director': [''], 'cast': ['Raven-Symoné', 'Issac Brown', 'Navia Robinson', 'Jason Maybaum', 'Sky Katz', 'Anneliese van der Pol'], 'country': ['United States'], 'release_year': 2016, 'duration': 4, 'listed_in': ['Comedy', 'Family', 'Fantasy'], 'rating': 'TV-G', 'description': 'Raven and Chelsea raise their three children together.'}

# %% [markdown]
# #### Apenas do titulo dos 5 primeiro Tv Show de fantasia:

# %%
query = collection.find({'$and': [{'type': {'$not': {'$eq': 'Movie'}}},
                                  {'listed_in': {'$eq': 'Fantasy'}}]}, {'_id': 0, 'title': 1}).limit(5)
for x in query:
    print(' ')
    print(x)
    print(' ')
# Out:
#
# {'title': "Zombies: Addison's Moonstone Mystery"}
#
#
# {'title': 'Disney Vampirina'}
#
#
# {'title': 'Miraculous: Tales Of Ladybug & Cat Noir'}
#
#
# {'title': 'Mira, Royal Detective'}
#
#
# {'title': "Disney Raven's Home"}

# %% [markdown]
# #### Apenas filmes 2020 até hoje

# %%
query = collection.find({'release_year': {'$gte': 2020}})

count = 0
for x in query:
    count += 1
print(count)
# Out:
# 239

# %%
query = collection.find({'release_year': {'$gte': 2020}}, {'_id':0, 'title': 1, 'type': 1}).limit(5)

for x in query:
    print(' ')
    print(x)
    print(' ')
# Out:
#
# {'type': 'Movie', 'title': 'The Queen Family Singalong'}
#
#
# {'type': 'TV Show', 'title': 'The Beatles: Get Back'}
#
#
# {'type': 'Movie', 'title': 'Becoming Cousteau'}
#
#
# {'type': 'TV Show', 'title': 'Hawkeye'}
#
#
# {'type': 'Movie', 'title': 'Adventure Thru the Walt Disney Archives'}

# %% [markdown]
# #### Serie de +1 temporada

# %%
query = collection.find({'$and':[{'duration': {'$gt': 1}}, {'type': 'TV Show'}]},
                    {'_id':0, 'title': 1, 'type':1, 'duration': 1}).limit(5)

for x in query:
    print(' ')
    print(x)
    print(' ')
# Out:
#
# {'type': 'TV Show', 'title': 'Port Protection Alaska', 'duration': 2}
#
#
# {'type': 'TV Show', 'title': 'Secrets of the Zoo: Tampa', 'duration': 2}
#
#
# {'type': 'TV Show', 'title': 'Dr. Oakley, Yukon Vet', 'duration': 10}
#
#
# {'type': 'TV Show', 'title': 'Disney Fancy Nancy', 'duration': 3}
#
#
# {'type': 'TV Show', 'title': 'Disney Amphibia', 'duration': 3}

# %% [markdown]
# ## Aggregation

# %% [markdown]
# <p> A 2ª Collection tem apenas o id do Filme/TV show e a descrição. </p>
# Vamos criar um relacionamento entre as collections para obter a informação do título, type e ano.

# %%
query = collection2.find({}, {'_id':0}).limit(5)

for x in query:
    print(' ')
    print(x)
    print(' ')
# Out:
#
# {'id_disney': 's1', 'descriptions': 'Join Mickey and the gang as they duck the halls!'}
#
#
# {'id_disney': 's2', 'descriptions': 'Santa Claus passes his magic bag to a new St. Nic.'}
#
#
# {'id_disney': 's3', 'descriptions': "Sid the Sloth is on Santa's naughty list."}
#
#
# {'id_disney': 's4', 'descriptions': 'This is real life, not just fantasy!'}
#
#
# {'id_disney': 's5', 'descriptions': 'A three-part documentary from Peter Jackson capturing a moment in music history with The Beatles.'}

# %%
query = collection2.aggregate([
    {
        '$lookup': {
            'from': "disney",
            'localField': "id_disney",
            'foreignField': "show_id",
            'as': "disney_data"
        }
    },
    {
        '$project':{
            '_id': 0,
            'show_id': 1,
            'description': 1,
            'disney_data': {
                '$arrayElemAt': ['$disney_data', 0]
            }
        }
    },
    {
        '$project':{
            'show_id': 1,
            'description': 1,
            'title': '$disney_data.title',
            'type': '$disney_data.type',
            'year': '$disney_data.release_year'
        }
    }
])

for x in query:
    print(' ')
    print(x)
    print(' ')
# Out:
#
# {'title': 'Duck the Halls: A Mickey Mouse Christmas Special', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Duck the Halls: A Mickey Mouse Christmas Special', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Duck the Halls: A Mickey Mouse Christmas Special', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Duck the Halls: A Mickey Mouse Christmas Special', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Duck the Halls: A Mickey Mouse Christmas Special', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Ernest Saves Christmas', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Ernest Saves Christmas', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Ernest Saves Christmas', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Ernest Saves Christmas', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Ernest Saves Christmas', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Ice Age: A Mammoth Christmas', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Ice Age: A Mammoth Christmas', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Ice Age: A Mammoth Christmas', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Ice Age: A Mammoth Christmas', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Ice Age: A Mammoth Christmas', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Queen Family Singalong', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Queen Family Singalong', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Queen Family Singalong', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Queen Family Singalong', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Queen Family Singalong', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Beatles: Get Back', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Beatles: Get Back', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Beatles: Get Back', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Beatles: Get Back', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Beatles: Get Back', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Becoming Cousteau', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Becoming Cousteau', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Becoming Cousteau', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Becoming Cousteau', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Becoming Cousteau', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Hawkeye', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Hawkeye', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Hawkeye', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Hawkeye', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Hawkeye', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Port Protection Alaska', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Port Protection Alaska', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Port Protection Alaska', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Port Protection Alaska', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Port Protection Alaska', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Secrets of the Zoo: Tampa', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Secrets of the Zoo: Tampa', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Secrets of the Zoo: Tampa', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Secrets of the Zoo: Tampa', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Secrets of the Zoo: Tampa', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'A Muppets Christmas: Letters To Santa', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'A Muppets Christmas: Letters To Santa', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'A Muppets Christmas: Letters To Santa', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'A Muppets Christmas: Letters To Santa', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'A Muppets Christmas: Letters To Santa', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'Adventure Thru the Walt Disney Archives', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Adventure Thru the Walt Disney Archives', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Adventure Thru the Walt Disney Archives', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Adventure Thru the Walt Disney Archives', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Adventure Thru the Walt Disney Archives', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Puppy for Hanukkah', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Puppy for Hanukkah', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Puppy for Hanukkah', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Puppy for Hanukkah', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Puppy for Hanukkah', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'The Pixar Story', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'The Pixar Story', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'The Pixar Story', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'The Pixar Story', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'The Pixar Story', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Dr. Oakley, Yukon Vet', 'type': 'TV Show', 'year': 2013}
#
#
# {'title': 'Dr. Oakley, Yukon Vet', 'type': 'TV Show', 'year': 2013}
#
#
# {'title': 'Dr. Oakley, Yukon Vet', 'type': 'TV Show', 'year': 2013}
#
#
# {'title': 'Dr. Oakley, Yukon Vet', 'type': 'TV Show', 'year': 2013}
#
#
# {'title': 'Dr. Oakley, Yukon Vet', 'type': 'TV Show', 'year': 2013}
#
#
# {'title': 'America the Beautiful', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'America the Beautiful', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'America the Beautiful', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'America the Beautiful', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'America the Beautiful', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Baymax!', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Baymax!', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Baymax!', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Baymax!', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Baymax!', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Ciao Alberto', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Ciao Alberto', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Ciao Alberto', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Ciao Alberto', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Ciao Alberto', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Disney Fancy Nancy', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Fancy Nancy', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Fancy Nancy', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Fancy Nancy', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Fancy Nancy', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Intertwined', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Disney Intertwined', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Disney Intertwined', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Disney Intertwined', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Disney Intertwined', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Enchanted', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Enchanted', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Enchanted', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Enchanted', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Enchanted', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Feast', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Feast', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Feast', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Feast', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Feast', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Frozen Fever', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Frozen Fever', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Frozen Fever', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Frozen Fever', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Frozen Fever', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Get a Horse!', 'type': 'Movie', 'year': 2013}
#
#
# {'title': 'Get a Horse!', 'type': 'Movie', 'year': 2013}
#
#
# {'title': 'Get a Horse!', 'type': 'Movie', 'year': 2013}
#
#
# {'title': 'Get a Horse!', 'type': 'Movie', 'year': 2013}
#
#
# {'title': 'Get a Horse!', 'type': 'Movie', 'year': 2013}
#
#
# {'title': 'Home Sweet Home Alone', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Home Sweet Home Alone', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Home Sweet Home Alone', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Home Sweet Home Alone', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Home Sweet Home Alone', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Jungle Cruise', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Jungle Cruise', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Jungle Cruise', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Jungle Cruise', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Jungle Cruise', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Limitless with Chris Hemsworth', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Limitless with Chris Hemsworth', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Limitless with Chris Hemsworth', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Limitless with Chris Hemsworth', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Limitless with Chris Hemsworth', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Marvel Studios’ 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Marvel Studios’ 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Marvel Studios’ 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Marvel Studios’ 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Marvel Studios’ 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Obi-Wan Kenobi', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Obi-Wan Kenobi', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Obi-Wan Kenobi', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Obi-Wan Kenobi', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Obi-Wan Kenobi', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Olaf Presents', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Olaf Presents', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Olaf Presents', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Olaf Presents', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Olaf Presents', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Paperman', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Paperman', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Paperman', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Paperman', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Paperman', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Pixar 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Pixar 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Pixar 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Pixar 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Pixar 2021 Disney+ Day Special', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Shang-Chi and The Legend of The Ten Rings', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Shang-Chi and The Legend of The Ten Rings', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Shang-Chi and The Legend of The Ten Rings', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Shang-Chi and The Legend of The Ten Rings', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Shang-Chi and The Legend of The Ten Rings', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Spin', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Spin', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Spin', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Spin', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Spin', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Tangled Ever After', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Tangled Ever After', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Tangled Ever After', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Tangled Ever After', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Tangled Ever After', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'The Ballad of Nessie', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Ballad of Nessie', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Ballad of Nessie', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Ballad of Nessie', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Ballad of Nessie', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Little Matchgirl', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'The Little Matchgirl', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'The Little Matchgirl', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'The Little Matchgirl', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'The Little Matchgirl', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'The Making of Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Making of Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Making of Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Making of Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Making of Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Proud Family: Louder and Prouder', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Proud Family: Louder and Prouder', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Proud Family: Louder and Prouder', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Proud Family: Louder and Prouder', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Proud Family: Louder and Prouder', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Simpsons in Plusaversary', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Simpsons in Plusaversary', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Simpsons in Plusaversary', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Simpsons in Plusaversary', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Simpsons in Plusaversary', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Tick Tock Tale', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Tick Tock Tale', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Tick Tock Tale', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Tick Tock Tale', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Tick Tock Tale', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Under the Helmet: The Legacy of Boba Fett', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under the Helmet: The Legacy of Boba Fett', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under the Helmet: The Legacy of Boba Fett', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under the Helmet: The Legacy of Boba Fett', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under the Helmet: The Legacy of Boba Fett', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Willow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Willow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Willow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Willow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Willow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Alvin and the Chipmunks: Chipwrecked', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Alvin and the Chipmunks: Chipwrecked', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Alvin and the Chipmunks: Chipwrecked', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Alvin and the Chipmunks: Chipwrecked', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Alvin and the Chipmunks: Chipwrecked', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Jingle All The Way', 'type': 'Movie', 'year': 1996}
#
#
# {'title': 'Jingle All The Way', 'type': 'Movie', 'year': 1996}
#
#
# {'title': 'Jingle All The Way', 'type': 'Movie', 'year': 1996}
#
#
# {'title': 'Jingle All The Way', 'type': 'Movie', 'year': 1996}
#
#
# {'title': 'Jingle All The Way', 'type': 'Movie', 'year': 1996}
#
#
# {'title': 'Jingle All the Way 2', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Jingle All the Way 2', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Jingle All the Way 2', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Jingle All the Way 2', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Jingle All the Way 2', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Prep & Landing: Operation Secret Santa', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Prep & Landing: Operation Secret Santa', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Prep & Landing: Operation Secret Santa', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Prep & Landing: Operation Secret Santa', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Prep & Landing: Operation Secret Santa', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'Santa Buddies: The Legend of Santa Paws', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Santa Buddies: The Legend of Santa Paws', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Santa Buddies: The Legend of Santa Paws', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Santa Buddies: The Legend of Santa Paws', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Santa Buddies: The Legend of Santa Paws', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Snow Buddies', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'Snow Buddies', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'Snow Buddies', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'Snow Buddies', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'Snow Buddies', 'type': 'Movie', 'year': 2008}
#
#
# {'title': 'Space Buddies', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Space Buddies', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Space Buddies', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Space Buddies', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Space Buddies', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'The Search for Santa Paws', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'The Search for Santa Paws', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'The Search for Santa Paws', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'The Search for Santa Paws', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'The Search for Santa Paws', 'type': 'Movie', 'year': 2010}
#
#
# {'title': 'X-Men: First Class', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'X-Men: First Class', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'X-Men: First Class', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'X-Men: First Class', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'X-Men: First Class', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Disney Amphibia', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Amphibia', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Amphibia', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Amphibia', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Disney Amphibia', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Photo Ark', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Photo Ark', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Photo Ark', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Photo Ark', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Photo Ark', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Storm Rising', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Storm Rising', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Storm Rising', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Storm Rising', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Storm Rising', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "Bob Ballard: An Explorer's Life", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Bob Ballard: An Explorer's Life", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Bob Ballard: An Explorer's Life", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Bob Ballard: An Explorer's Life", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Bob Ballard: An Explorer's Life", 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'McFarland, USA', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'McFarland, USA', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'McFarland, USA', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'McFarland, USA', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'McFarland, USA', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Rookie of the Year', 'type': 'Movie', 'year': 1993}
#
#
# {'title': 'Rookie of the Year', 'type': 'Movie', 'year': 1993}
#
#
# {'title': 'Rookie of the Year', 'type': 'Movie', 'year': 1993}
#
#
# {'title': 'Rookie of the Year', 'type': 'Movie', 'year': 1993}
#
#
# {'title': 'Rookie of the Year', 'type': 'Movie', 'year': 1993}
#
#
# {'title': 'Thumbelina', 'type': 'Movie', 'year': 1994}
#
#
# {'title': 'Thumbelina', 'type': 'Movie', 'year': 1994}
#
#
# {'title': 'Thumbelina', 'type': 'Movie', 'year': 1994}
#
#
# {'title': 'Thumbelina', 'type': 'Movie', 'year': 1994}
#
#
# {'title': 'Thumbelina', 'type': 'Movie', 'year': 1994}
#
#
# {'title': 'PJ Masks', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'PJ Masks', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'PJ Masks', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'PJ Masks', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'PJ Masks', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'The Wild Life of Dr. Ole', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wild Life of Dr. Ole', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wild Life of Dr. Ole', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wild Life of Dr. Ole', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wild Life of Dr. Ole', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Lost Cities with Albert Lin: The Great Flood', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Lost Cities with Albert Lin: The Great Flood', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Lost Cities with Albert Lin: The Great Flood', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Lost Cities with Albert Lin: The Great Flood', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Lost Cities with Albert Lin: The Great Flood', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Megacity of the Maya Warriors', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Megacity of the Maya Warriors', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Megacity of the Maya Warriors', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Megacity of the Maya Warriors', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Megacity of the Maya Warriors', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Apollo: Back To The Moon', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Apollo: Back To The Moon', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Apollo: Back To The Moon', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Apollo: Back To The Moon', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Apollo: Back To The Moon', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Just Beyond', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Just Beyond', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Just Beyond', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Just Beyond', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Just Beyond', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Secrets Of The Zoo: Down Under', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets Of The Zoo: Down Under', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets Of The Zoo: Down Under', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets Of The Zoo: Down Under', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets Of The Zoo: Down Under', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets of the Zoo: North Carolina', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets of the Zoo: North Carolina', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets of the Zoo: North Carolina', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets of the Zoo: North Carolina', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Secrets of the Zoo: North Carolina', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'The Wizard of Paws', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wizard of Paws', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wizard of Paws', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wizard of Paws', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Wizard of Paws', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "Zombies: Addison's Moonstone Mystery", 'type': 'TV Show', 'year': 2020}
#
#
# {'title': "Zombies: Addison's Moonstone Mystery", 'type': 'TV Show', 'year': 2020}
#
#
# {'title': "Zombies: Addison's Moonstone Mystery", 'type': 'TV Show', 'year': 2020}
#
#
# {'title': "Zombies: Addison's Moonstone Mystery", 'type': 'TV Show', 'year': 2020}
#
#
# {'title': "Zombies: Addison's Moonstone Mystery", 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Just Roll With It: You Decide Live!', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'Just Roll With It: You Decide Live!', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'Just Roll With It: You Decide Live!', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'Just Roll With It: You Decide Live!', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'Just Roll With It: You Decide Live!', 'type': 'Movie', 'year': 2019}
#
#
# {'title': "Mickey's Tale of Two Witches", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Mickey's Tale of Two Witches", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Mickey's Tale of Two Witches", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Mickey's Tale of Two Witches", 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Mickey's Tale of Two Witches", 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Muppets Haunted Mansion', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Muppets Haunted Mansion', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Muppets Haunted Mansion', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Muppets Haunted Mansion', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Muppets Haunted Mansion', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Most Magical Story on Earth: 50 Years of Walt Disney World', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Most Magical Story on Earth: 50 Years of Walt Disney World', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Most Magical Story on Earth: 50 Years of Walt Disney World', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Most Magical Story on Earth: 50 Years of Walt Disney World', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'The Most Magical Story on Earth: 50 Years of Walt Disney World', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under Wraps', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under Wraps', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under Wraps', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under Wraps', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Under Wraps', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Among the Stars', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Among the Stars', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Among the Stars', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Among the Stars', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Among the Stars', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Black Widow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Black Widow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Black Widow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Black Widow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Black Widow', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Drain the Oceans', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Drain the Oceans', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Drain the Oceans', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Drain the Oceans', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Drain the Oceans', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Drain The Oceans: The Mississippi River & Arctic War', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Drain The Oceans: The Mississippi River & Arctic War', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Drain The Oceans: The Mississippi River & Arctic War', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Drain The Oceans: The Mississippi River & Arctic War', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Drain The Oceans: The Mississippi River & Arctic War', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Fauci', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Fauci', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Fauci', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Fauci', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Fauci', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'IMPACT with Gal Gadot', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'IMPACT with Gal Gadot', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'IMPACT with Gal Gadot', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'IMPACT with Gal Gadot', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'IMPACT with Gal Gadot', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Ghost and Molly McGee', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Ghost and Molly McGee', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Ghost and Molly McGee', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Ghost and Molly McGee', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Ghost and Molly McGee', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Alvin and the Chipmunks', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Alvin and the Chipmunks', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Alvin and the Chipmunks', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Alvin and the Chipmunks', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Alvin and the Chipmunks', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Alvin and the Chipmunks: The Road Chip', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Alvin and the Chipmunks: The Road Chip', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Alvin and the Chipmunks: The Road Chip', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Alvin and the Chipmunks: The Road Chip', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Alvin and the Chipmunks: The Road Chip', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'LEGO Star Wars Terrifying Tales', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'LEGO Star Wars Terrifying Tales', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'LEGO Star Wars Terrifying Tales', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'LEGO Star Wars Terrifying Tales', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'LEGO Star Wars Terrifying Tales', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Maleficent', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Maleficent', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Maleficent', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Maleficent', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Maleficent', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'The Scariest Story Ever: A Mickey Mouse Halloween Spooktacular', 'type': 'Movie', 'year': 2017}
#
#
# {'title': 'The Scariest Story Ever: A Mickey Mouse Halloween Spooktacular', 'type': 'Movie', 'year': 2017}
#
#
# {'title': 'The Scariest Story Ever: A Mickey Mouse Halloween Spooktacular', 'type': 'Movie', 'year': 2017}
#
#
# {'title': 'The Scariest Story Ever: A Mickey Mouse Halloween Spooktacular', 'type': 'Movie', 'year': 2017}
#
#
# {'title': 'The Scariest Story Ever: A Mickey Mouse Halloween Spooktacular', 'type': 'Movie', 'year': 2017}
#
#
# {'title': 'Disney Vampirina', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Disney Vampirina', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Disney Vampirina', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Disney Vampirina', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': 'Disney Vampirina', 'type': 'TV Show', 'year': 2017}
#
#
# {'title': "Disney's Magic Bake-Off", 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "Disney's Magic Bake-Off", 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "Disney's Magic Bake-Off", 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "Disney's Magic Bake-Off", 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "Disney's Magic Bake-Off", 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Great Barrier Reef', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Great Barrier Reef', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Great Barrier Reef', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Great Barrier Reef', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Great Barrier Reef', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Ready for Preschool', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Ready for Preschool', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Ready for Preschool', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Ready for Preschool', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Ready for Preschool', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Rolie Polie Olie', 'type': 'TV Show', 'year': 1998}
#
#
# {'title': 'Rolie Polie Olie', 'type': 'TV Show', 'year': 1998}
#
#
# {'title': 'Rolie Polie Olie', 'type': 'TV Show', 'year': 1998}
#
#
# {'title': 'Rolie Polie Olie', 'type': 'TV Show', 'year': 1998}
#
#
# {'title': 'Rolie Polie Olie', 'type': 'TV Show', 'year': 1998}
#
#
# {'title': 'Star Wars Galaxy of Sounds', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars Galaxy of Sounds', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars Galaxy of Sounds', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars Galaxy of Sounds', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars Galaxy of Sounds', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Hatcher Family Dairy', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Hatcher Family Dairy', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Hatcher Family Dairy', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Hatcher Family Dairy', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Hatcher Family Dairy', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'The Simpsons', 'type': 'TV Show', 'year': 1989}
#
#
# {'title': 'The Simpsons', 'type': 'TV Show', 'year': 1989}
#
#
# {'title': 'The Simpsons', 'type': 'TV Show', 'year': 1989}
#
#
# {'title': 'The Simpsons', 'type': 'TV Show', 'year': 1989}
#
#
# {'title': 'The Simpsons', 'type': 'TV Show', 'year': 1989}
#
#
# {'title': 'A Spark Story', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'A Spark Story', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'A Spark Story', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'A Spark Story', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'A Spark Story', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Spooky Buddies', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Spooky Buddies', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Spooky Buddies', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Spooky Buddies', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Spooky Buddies', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'The Fault in Our Stars', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'The Fault in Our Stars', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'The Fault in Our Stars', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'The Fault in Our Stars', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'The Fault in Our Stars', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Dog: Impossible', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Dog: Impossible', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Dog: Impossible', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Dog: Impossible', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Dog: Impossible', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Spidey And His Amazing Friends', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Spidey And His Amazing Friends', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Spidey And His Amazing Friends', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Spidey And His Amazing Friends', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Spidey And His Amazing Friends', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars: Visions', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars: Visions', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars: Visions', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars: Visions', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Star Wars: Visions', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Confessions of a Shopaholic', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Confessions of a Shopaholic', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Confessions of a Shopaholic', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Confessions of a Shopaholic', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Confessions of a Shopaholic', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Descendants: Royal Wedding', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Descendants: Royal Wedding', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Descendants: Royal Wedding', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Descendants: Royal Wedding', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Descendants: Royal Wedding', 'type': 'Movie', 'year': 2021}
#
#
# {'title': "Disney's Broadway Hits at London's Royal Albert Hall", 'type': 'Movie', 'year': 2016}
#
#
# {'title': "Disney's Broadway Hits at London's Royal Albert Hall", 'type': 'Movie', 'year': 2016}
#
#
# {'title': "Disney's Broadway Hits at London's Royal Albert Hall", 'type': 'Movie', 'year': 2016}
#
#
# {'title': "Disney's Broadway Hits at London's Royal Albert Hall", 'type': 'Movie', 'year': 2016}
#
#
# {'title': "Disney's Broadway Hits at London's Royal Albert Hall", 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Flooded Tombs of the Nile', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Flooded Tombs of the Nile', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Flooded Tombs of the Nile', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Flooded Tombs of the Nile', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Flooded Tombs of the Nile', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Jade Eyed Leopard', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Jade Eyed Leopard', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Jade Eyed Leopard', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Jade Eyed Leopard', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Jade Eyed Leopard', 'type': 'Movie', 'year': 2020}
#
#
# {'title': 'Nona', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Nona', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Nona', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Nona', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Nona', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Smoky Mountain Park Rangers', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Smoky Mountain Park Rangers', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Smoky Mountain Park Rangers', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Smoky Mountain Park Rangers', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Smoky Mountain Park Rangers', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Life Below Zero', 'type': 'TV Show', 'year': 2012}
#
#
# {'title': 'Life Below Zero', 'type': 'TV Show', 'year': 2012}
#
#
# {'title': 'Life Below Zero', 'type': 'TV Show', 'year': 2012}
#
#
# {'title': 'Life Below Zero', 'type': 'TV Show', 'year': 2012}
#
#
# {'title': 'Life Below Zero', 'type': 'TV Show', 'year': 2012}
#
#
# {'title': 'Miraculous: Tales Of Ladybug & Cat Noir', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Miraculous: Tales Of Ladybug & Cat Noir', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Miraculous: Tales Of Ladybug & Cat Noir', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Miraculous: Tales Of Ladybug & Cat Noir', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Miraculous: Tales Of Ladybug & Cat Noir', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Unknown Waters with Jeremy Wade', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Unknown Waters with Jeremy Wade', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Unknown Waters with Jeremy Wade', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Unknown Waters with Jeremy Wade', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Unknown Waters with Jeremy Wade', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Far Away From Raven’s Home', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Far Away From Raven’s Home', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Far Away From Raven’s Home', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Far Away From Raven’s Home', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Far Away From Raven’s Home', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Twenty Something', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Twenty Something', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Twenty Something', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Twenty Something', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Twenty Something', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Doogie Kamealoha, M.D.', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Doogie Kamealoha, M.D.', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Doogie Kamealoha, M.D.', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Doogie Kamealoha, M.D.', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Doogie Kamealoha, M.D.', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Mira, Royal Detective', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Mira, Royal Detective', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Mira, Royal Detective', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Mira, Royal Detective', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Mira, Royal Detective', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Pepper Ann', 'type': 'TV Show', 'year': 1997}
#
#
# {'title': 'Pepper Ann', 'type': 'TV Show', 'year': 1997}
#
#
# {'title': 'Pepper Ann', 'type': 'TV Show', 'year': 1997}
#
#
# {'title': 'Pepper Ann', 'type': 'TV Show', 'year': 1997}
#
#
# {'title': 'Pepper Ann', 'type': 'TV Show', 'year': 1997}
#
#
# {'title': 'The Incredible Dr. Pol', 'type': 'TV Show', 'year': 2011}
#
#
# {'title': 'The Incredible Dr. Pol', 'type': 'TV Show', 'year': 2011}
#
#
# {'title': 'The Incredible Dr. Pol', 'type': 'TV Show', 'year': 2011}
#
#
# {'title': 'The Incredible Dr. Pol', 'type': 'TV Show', 'year': 2011}
#
#
# {'title': 'The Incredible Dr. Pol', 'type': 'TV Show', 'year': 2011}
#
#
# {'title': 'Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Happier Than Ever: A Love Letter to Los Angeles', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'X-Men: Dark Phoenix', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'X-Men: Dark Phoenix', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'X-Men: Dark Phoenix', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'X-Men: Dark Phoenix', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'X-Men: Dark Phoenix', 'type': 'Movie', 'year': 2019}
#
#
# {'title': 'Alaska Animal Rescue', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Alaska Animal Rescue', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Alaska Animal Rescue', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Alaska Animal Rescue', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Alaska Animal Rescue', 'type': 'TV Show', 'year': 2019}
#
#
# {'title': 'Dug Days', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Dug Days', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Dug Days', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Dug Days', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Dug Days', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Cruella', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Cruella', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Cruella', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Cruella', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Cruella', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Dan in Real Life', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Dan in Real Life', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Dan in Real Life', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Dan in Real Life', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Dan in Real Life', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Disney Princess Remixed - An Ultimate Princess Celebration', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Disney Princess Remixed - An Ultimate Princess Celebration', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Disney Princess Remixed - An Ultimate Princess Celebration', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Disney Princess Remixed - An Ultimate Princess Celebration', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Disney Princess Remixed - An Ultimate Princess Celebration', 'type': 'Movie', 'year': 2021}
#
#
# {'title': 'Marvel One-Shot: All Hail the King', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Marvel One-Shot: All Hail the King', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Marvel One-Shot: All Hail the King', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Marvel One-Shot: All Hail the King', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Marvel One-Shot: All Hail the King', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Underdog', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Underdog', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Underdog', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Underdog', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Underdog', 'type': 'Movie', 'year': 2007}
#
#
# {'title': "Dr. K's Exotic Animal ER", 'type': 'TV Show', 'year': 2014}
#
#
# {'title': "Dr. K's Exotic Animal ER", 'type': 'TV Show', 'year': 2014}
#
#
# {'title': "Dr. K's Exotic Animal ER", 'type': 'TV Show', 'year': 2014}
#
#
# {'title': "Dr. K's Exotic Animal ER", 'type': 'TV Show', 'year': 2014}
#
#
# {'title': "Dr. K's Exotic Animal ER", 'type': 'TV Show', 'year': 2014}
#
#
# {'title': 'Gigantosaurus', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Gigantosaurus', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Gigantosaurus', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Gigantosaurus', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Gigantosaurus', 'type': 'TV Show', 'year': 2018}
#
#
# {'title': 'Life Below Zero: Next Generation', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Life Below Zero: Next Generation', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Life Below Zero: Next Generation', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Life Below Zero: Next Generation', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Life Below Zero: Next Generation', 'type': 'TV Show', 'year': 2020}
#
#
# {'title': 'Eragon', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Eragon', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Eragon', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Eragon', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Eragon', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Growing Up Animal', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Growing Up Animal', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Growing Up Animal', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Growing Up Animal', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Growing Up Animal', 'type': 'TV Show', 'year': 2021}
#
#
# {'title': 'Fantastic Four', 'type': 'Movie', 'year': 2005}
#
#
# {'title': 'Fantastic Four', 'type': 'Movie', 'year': 2005}
#
#
# {'title': 'Fantastic Four', 'type': 'Movie', 'year': 2005}
#
#
# {'title': 'Fantastic Four', 'type': 'Movie', 'year': 2005}
#
#
# {'title': 'Fantastic Four', 'type': 'Movie', 'year': 2005}
#
#
# {'title': 'X-Men', 'type': 'Movie', 'year': 2000}
#
#
# {'title': 'X-Men', 'type': 'Movie', 'year': 2000}
#
#
# {'title': 'X-Men', 'type': 'Movie', 'year': 2000}
#
#
# {'title': 'X-Men', 'type': 'Movie', 'year': 2000}
#
#
# {'title': 'X-Men', 'type': 'Movie', 'year': 2000}
#
#
# {'title': "America's Funniest Home Videos: Animal Edition", 'type': 'TV Show', 'year': 2021}
#
#
# {'title': "America's Funniest Home Videos: Animal Edition", 'type': 'TV Show', 'year': 2021}
#
#
# ...
#
# {'title': 'White Fang', 'type': 'Movie', 'year': 1991}
#
#
# {'title': 'White Fang', 'type': 'Movie', 'year': 1991}
#
#
# {'title': 'White Fang', 'type': 'Movie', 'year': 1991}
#
#
# {'title': 'White Fang', 'type': 'Movie', 'year': 1991}
#
#
# {'title': 'Who Framed Roger Rabbit', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Who Framed Roger Rabbit', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Who Framed Roger Rabbit', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Who Framed Roger Rabbit', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Who Framed Roger Rabbit', 'type': 'Movie', 'year': 1988}
#
#
# {'title': 'Wild Yellowstone', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Wild Yellowstone', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Wild Yellowstone', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Wild Yellowstone', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Wild Yellowstone', 'type': 'TV Show', 'year': 2015}
#
#
# {'title': 'Winged Seduction: Birds of Paradise', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Winged Seduction: Birds of Paradise', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Winged Seduction: Birds of Paradise', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Winged Seduction: Birds of Paradise', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Winged Seduction: Birds of Paradise', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Winnie the Pooh', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Winnie the Pooh', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Winnie the Pooh', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Winnie the Pooh', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Winnie the Pooh', 'type': 'Movie', 'year': 2011}
#
#
# {'title': 'Winnie the Pooh: A Very Merry Pooh Year', 'type': 'Movie', 'year': 2002}
#
#
# {'title': 'Winnie the Pooh: A Very Merry Pooh Year', 'type': 'Movie', 'year': 2002}
#
#
# {'title': 'Winnie the Pooh: A Very Merry Pooh Year', 'type': 'Movie', 'year': 2002}
#
#
# {'title': 'Winnie the Pooh: A Very Merry Pooh Year', 'type': 'Movie', 'year': 2002}
#
#
# {'title': 'Winnie the Pooh: A Very Merry Pooh Year', 'type': 'Movie', 'year': 2002}
#
#
# {'title': 'Winnie the Pooh: Springtime with Roo', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Winnie the Pooh: Springtime with Roo', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Winnie the Pooh: Springtime with Roo', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Winnie the Pooh: Springtime with Roo', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Winnie the Pooh: Springtime with Roo', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Winter Storage', 'type': 'Movie', 'year': 1949}
#
#
# {'title': 'Winter Storage', 'type': 'Movie', 'year': 1949}
#
#
# {'title': 'Winter Storage', 'type': 'Movie', 'year': 1949}
#
#
# {'title': 'Winter Storage', 'type': 'Movie', 'year': 1949}
#
#
# {'title': 'Winter Storage', 'type': 'Movie', 'year': 1949}
#
#
# {'title': 'Wizards of Waverly Place', 'type': 'TV Show', 'year': 2007}
#
#
# {'title': 'Wizards of Waverly Place', 'type': 'TV Show', 'year': 2007}
#
#
# {'title': 'Wizards of Waverly Place', 'type': 'TV Show', 'year': 2007}
#
#
# {'title': 'Wizards of Waverly Place', 'type': 'TV Show', 'year': 2007}
#
#
# {'title': 'Wizards of Waverly Place', 'type': 'TV Show', 'year': 2007}
#
#
# {'title': 'Wizards of Waverly Place: The Movie', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Wizards of Waverly Place: The Movie', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Wizards of Waverly Place: The Movie', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Wizards of Waverly Place: The Movie', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Wizards of Waverly Place: The Movie', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Wolverine and The X-Men', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Wolverine and The X-Men', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Wolverine and The X-Men', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Wolverine and The X-Men', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Wolverine and The X-Men', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': "World's Greatest Dogs", 'type': 'Movie', 'year': 2015}
#
#
# {'title': "World's Greatest Dogs", 'type': 'Movie', 'year': 2015}
#
#
# {'title': "World's Greatest Dogs", 'type': 'Movie', 'year': 2015}
#
#
# {'title': "World's Greatest Dogs", 'type': 'Movie', 'year': 2015}
#
#
# {'title': "World's Greatest Dogs", 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Wreck-It Ralph', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Wreck-It Ralph', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Wreck-It Ralph', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Wreck-It Ralph', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Wreck-It Ralph', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'X-Men: Evolution', 'type': 'TV Show', 'year': 2000}
#
#
# {'title': 'X-Men: Evolution', 'type': 'TV Show', 'year': 2000}
#
#
# {'title': 'X-Men: Evolution', 'type': 'TV Show', 'year': 2000}
#
#
# {'title': 'X-Men: Evolution', 'type': 'TV Show', 'year': 2000}
#
#
# {'title': 'X-Men: Evolution', 'type': 'TV Show', 'year': 2000}
#
#
# {'title': 'Ye Olden Days', 'type': 'Movie', 'year': 1933}
#
#
# {'title': 'Ye Olden Days', 'type': 'Movie', 'year': 1933}
#
#
# {'title': 'Ye Olden Days', 'type': 'Movie', 'year': 1933}
#
#
# {'title': 'Ye Olden Days', 'type': 'Movie', 'year': 1933}
#
#
# {'title': 'Ye Olden Days', 'type': 'Movie', 'year': 1933}
#
#
# {'title': 'Yellowstone Cubs', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'Yellowstone Cubs', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'Yellowstone Cubs', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'Yellowstone Cubs', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'Yellowstone Cubs', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'You Lucky Dog', 'type': 'Movie', 'year': 1998}
#
#
# {'title': 'You Lucky Dog', 'type': 'Movie', 'year': 1998}
#
#
# {'title': 'You Lucky Dog', 'type': 'Movie', 'year': 1998}
#
#
# {'title': 'You Lucky Dog', 'type': 'Movie', 'year': 1998}
#
#
# {'title': 'You Lucky Dog', 'type': 'Movie', 'year': 1998}
#
#
# {'title': 'You Wish!', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'You Wish!', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'You Wish!', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'You Wish!', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'You Wish!', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'Your Friend the Rat', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Your Friend the Rat', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Your Friend the Rat', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Your Friend the Rat', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Your Friend the Rat', 'type': 'Movie', 'year': 2007}
#
#
# {'title': 'Z-O-M-B-I-E-S', 'type': 'Movie', 'year': 2018}
#
#
# {'title': 'Z-O-M-B-I-E-S', 'type': 'Movie', 'year': 2018}
#
#
# {'title': 'Z-O-M-B-I-E-S', 'type': 'Movie', 'year': 2018}
#
#
# {'title': 'Z-O-M-B-I-E-S', 'type': 'Movie', 'year': 2018}
#
#
# {'title': 'Z-O-M-B-I-E-S', 'type': 'Movie', 'year': 2018}
#
#
# {'title': 'Zapped', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Zapped', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Zapped', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Zapped', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Zapped', 'type': 'Movie', 'year': 2014}
#
#
# {'title': 'Zenon: Girl of the 21st Century', 'type': 'Movie', 'year': 1999}
#
#
# {'title': 'Zenon: Girl of the 21st Century', 'type': 'Movie', 'year': 1999}
#
#
# {'title': 'Zenon: Girl of the 21st Century', 'type': 'Movie', 'year': 1999}
#
#
# {'title': 'Zenon: Girl of the 21st Century', 'type': 'Movie', 'year': 1999}
#
#
# {'title': 'Zenon: Girl of the 21st Century', 'type': 'Movie', 'year': 1999}
#
#
# {'title': 'Zenon: The Zequel', 'type': 'Movie', 'year': 2001}
#
#
# {'title': 'Zenon: The Zequel', 'type': 'Movie', 'year': 2001}
#
#
# {'title': 'Zenon: The Zequel', 'type': 'Movie', 'year': 2001}
#
#
# {'title': 'Zenon: The Zequel', 'type': 'Movie', 'year': 2001}
#
#
# {'title': 'Zenon: The Zequel', 'type': 'Movie', 'year': 2001}
#
#
# {'title': 'Zenon: Z3', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Zenon: Z3', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Zenon: Z3', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Zenon: Z3', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Zenon: Z3', 'type': 'Movie', 'year': 2004}
#
#
# {'title': 'Zootopia', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Zootopia', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Zootopia', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Zootopia', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Zootopia', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Bedknobs and Broomsticks', 'type': 'Movie', 'year': 1971}
#
#
# {'title': 'Bedknobs and Broomsticks', 'type': 'Movie', 'year': 1971}
#
#
# {'title': 'Bedknobs and Broomsticks', 'type': 'Movie', 'year': 1971}
#
#
# {'title': 'Bedknobs and Broomsticks', 'type': 'Movie', 'year': 1971}
#
#
# {'title': 'Bedknobs and Broomsticks', 'type': 'Movie', 'year': 1971}
#
#
# {'title': "Blackbeard's Ghost", 'type': 'Movie', 'year': 1968}
#
#
# {'title': "Blackbeard's Ghost", 'type': 'Movie', 'year': 1968}
#
#
# {'title': "Blackbeard's Ghost", 'type': 'Movie', 'year': 1968}
#
#
# {'title': "Blackbeard's Ghost", 'type': 'Movie', 'year': 1968}
#
#
# {'title': "Blackbeard's Ghost", 'type': 'Movie', 'year': 1968}
#
#
# {'title': 'Brave Little Tailor', 'type': 'Movie', 'year': 1938}
#
#
# {'title': 'Brave Little Tailor', 'type': 'Movie', 'year': 1938}
#
#
# {'title': 'Brave Little Tailor', 'type': 'Movie', 'year': 1938}
#
#
# {'title': 'Brave Little Tailor', 'type': 'Movie', 'year': 1938}
#
#
# {'title': 'Brave Little Tailor', 'type': 'Movie', 'year': 1938}
#
#
# {'title': 'Justin Morgan had a Horse', 'type': 'Movie', 'year': 1972}
#
#
# {'title': 'Justin Morgan had a Horse', 'type': 'Movie', 'year': 1972}
#
#
# {'title': 'Justin Morgan had a Horse', 'type': 'Movie', 'year': 1972}
#
#
# {'title': 'Justin Morgan had a Horse', 'type': 'Movie', 'year': 1972}
#
#
# {'title': 'Justin Morgan had a Horse', 'type': 'Movie', 'year': 1972}
#
#
# {'title': "Lady and the Tramp II: Scamp's Adventure", 'type': 'Movie', 'year': 2001}
#
#
# {'title': "Lady and the Tramp II: Scamp's Adventure", 'type': 'Movie', 'year': 2001}
#
#
# {'title': "Lady and the Tramp II: Scamp's Adventure", 'type': 'Movie', 'year': 2001}
#
#
# {'title': "Lady and the Tramp II: Scamp's Adventure", 'type': 'Movie', 'year': 2001}
#
#
# {'title': "Lady and the Tramp II: Scamp's Adventure", 'type': 'Movie', 'year': 2001}
#
#
# {'title': 'Smart Guy', 'type': 'TV Show', 'year': 1996}
#
#
# {'title': 'Smart Guy', 'type': 'TV Show', 'year': 1996}
#
#
# {'title': 'Smart Guy', 'type': 'TV Show', 'year': 1996}
#
#
# {'title': 'Smart Guy', 'type': 'TV Show', 'year': 1996}
#
#
# {'title': 'Smart Guy', 'type': 'TV Show', 'year': 1996}
#
#
# {'title': 'The Cat from Outer Space', 'type': 'Movie', 'year': 1978}
#
#
# {'title': 'The Cat from Outer Space', 'type': 'Movie', 'year': 1978}
#
#
# {'title': 'The Cat from Outer Space', 'type': 'Movie', 'year': 1978}
#
#
# {'title': 'The Cat from Outer Space', 'type': 'Movie', 'year': 1978}
#
#
# {'title': 'The Cat from Outer Space', 'type': 'Movie', 'year': 1978}
#
#
# {'title': 'The Great Mouse Detective', 'type': 'Movie', 'year': 1986}
#
#
# {'title': 'The Great Mouse Detective', 'type': 'Movie', 'year': 1986}
#
#
# {'title': 'The Great Mouse Detective', 'type': 'Movie', 'year': 1986}
#
#
# {'title': 'The Great Mouse Detective', 'type': 'Movie', 'year': 1986}
#
#
# {'title': 'The Great Mouse Detective', 'type': 'Movie', 'year': 1986}
#
#
# {'title': 'The Sword in the Stone', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'The Sword in the Stone', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'The Sword in the Stone', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'The Sword in the Stone', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'The Sword in the Stone', 'type': 'Movie', 'year': 1963}
#
#
# {'title': 'Those Calloways', 'type': 'Movie', 'year': 1965}
#
#
# {'title': 'Those Calloways', 'type': 'Movie', 'year': 1965}
#
#
# {'title': 'Those Calloways', 'type': 'Movie', 'year': 1965}
#
#
# {'title': 'Those Calloways', 'type': 'Movie', 'year': 1965}
#
#
# {'title': 'Those Calloways', 'type': 'Movie', 'year': 1965}
#
#
# {'title': 'Disney Kirby Buckets', 'type': 'TV Show', 'year': 2014}
#
#
# {'title': 'Disney Kirby Buckets', 'type': 'TV Show', 'year': 2014}
#
#
# {'title': 'Disney Kirby Buckets', 'type': 'TV Show', 'year': 2014}
#
#
# {'title': 'Disney Kirby Buckets', 'type': 'TV Show', 'year': 2014}
#
#
# {'title': 'Disney Kirby Buckets', 'type': 'TV Show', 'year': 2014}
#
#
# {'title': 'Disney Mech-X4', 'type': 'TV Show', 'year': 2016}
#
#
# {'title': 'Disney Mech-X4', 'type': 'TV Show', 'year': 2016}
#
#
# {'title': 'Disney Mech-X4', 'type': 'TV Show', 'year': 2016}
#
#
# {'title': 'Disney Mech-X4', 'type': 'TV Show', 'year': 2016}
#
#
# {'title': 'Disney Mech-X4', 'type': 'TV Show', 'year': 2016}
#
#
# {'title': 'Imagination Movers', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Imagination Movers', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Imagination Movers', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Imagination Movers', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Imagination Movers', 'type': 'TV Show', 'year': 2008}
#
#
# {'title': 'Tomorrowland', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Tomorrowland', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Tomorrowland', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Tomorrowland', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Tomorrowland', 'type': 'Movie', 'year': 2015}
#
#
# {'title': 'Aquamarine', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Aquamarine', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Aquamarine', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Aquamarine', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Aquamarine', 'type': 'Movie', 'year': 2006}
#
#
# {'title': 'Ice Age: Dawn Of The Dinosaurs', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Ice Age: Dawn Of The Dinosaurs', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Ice Age: Dawn Of The Dinosaurs', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Ice Age: Dawn Of The Dinosaurs', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Ice Age: Dawn Of The Dinosaurs', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'X-Men Origins: Wolverine', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'X-Men Origins: Wolverine', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'X-Men Origins: Wolverine', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'X-Men Origins: Wolverine', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'X-Men Origins: Wolverine', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Night at the Museum: Battle of the Smithsonian', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Night at the Museum: Battle of the Smithsonian', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Night at the Museum: Battle of the Smithsonian', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Night at the Museum: Battle of the Smithsonian', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Night at the Museum: Battle of the Smithsonian', 'type': 'Movie', 'year': 2009}
#
#
# {'title': 'Eddie the Eagle', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Eddie the Eagle', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Eddie the Eagle', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Eddie the Eagle', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Eddie the Eagle', 'type': 'Movie', 'year': 2016}
#
#
# {'title': 'Bend It Like Beckham', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'Bend It Like Beckham', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'Bend It Like Beckham', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'Bend It Like Beckham', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'Bend It Like Beckham', 'type': 'Movie', 'year': 2003}
#
#
# {'title': 'Captain Sparky vs. The Flying Saucers', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Captain Sparky vs. The Flying Saucers', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Captain Sparky vs. The Flying Saucers', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Captain Sparky vs. The Flying Saucers', 'type': 'Movie', 'year': 2012}
#
#
# {'title': 'Captain Sparky vs. The Flying Saucers', 'type': 'Movie', 'year': 2012}
